# %% [markdown]
# <br><font face="Times New Roman" size=5><div dir=ltr align=center>
# <font color=blue size=8>
#     Introduction to Machine Learning <br>
# <font color=red size=5>
#     Sharif University of Technology - Computer Engineering Department <br>
#     Fall 2022<br> <br>
# <font color=black size=6>
#     Homework 2: Practical - Decision Tree
# <font color=black size=4>
#     Hamidreza Yaghoubi
#
# <br><br>
# <font size=4>
# In this homework, we are going to implement the Classification Decision Tree. Keep in mind to complete all of the following questions and write your own codes in the TODO cells.

# %% [markdown]
# <font face="Times New Roman" size=4><div dir=ltr>
# # Problem 2: Classification Decision Tree (100 points)
# We will implement a Classification Decision Tree from scratch in the following problem. Then we will use our model to predict malignant and benign breast cancer. For this purpose, we will use the breast_cancer.csv dataset which you can find more details about it <a href="https://www.kaggle.com/datasets/merishnasuwal/breast-cancer-prediction-dataset"><font face="Roboto">here</font></a>.

# %%
# Mohammad Mahdi Abootorabi
# 98105557

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from math import log
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <font face="Times New Roman" size=4><div dir=ltr>
# ## Classification Decision Tree Class (60 points)
# In this section, you only need to fill TODO parts. You can find the logic and formula in both course slides and the web, but fill it out on your own.

# %%
class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value

    def is_leaf(self):
        if self.value is not None:
            return True
        return False

# %%
class DecisionTree:
    def __init__(self, max_depth=None, min_samples_split=2):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.root = None

    def is_splitting_finished(self, depth, num_class_labels, num_samples):
        #TODO
        if depth == self.max_depth or num_samples < self.min_samples_split or num_class_labels == 1:
            return True
        return False

    def split(self, X, y, feature, threshold):
        left_indexes = X[feature] <= threshold
        right_indexes = -left_indexes
        X_left = X[left_indexes]
        y_left = y[left_indexes]
        X_right = X[right_indexes]
        y_right = y[right_indexes]

        return X_left, X_right, y_left, y_right

    def entropy(self, y): 
        #TODO
        _, counts = np.unique(y, return_counts=True)
        p = counts / len(y)
        ent = -sum(i * np.log2(i) for i in p if i > 0)
        return ent


    def information_gain(self, X, y, feature, threshold):
        #TODO
        X_left, X_right, y_left, y_right = self.split(X, y, feature, threshold)
        H_y = self.entropy(y)
        if len(y_left) == 0 or len(y_right) == 0: 
            return 0
        H_y_given_x = ((len(y_left) / len(y)) * self.entropy(y_left)) + ((len(y_right) / len(y)) * self.entropy(y_right))
        ig = H_y - H_y_given_x
        return ig

    def best_split(self, X, y):
        #TODO
        best_information_gain = 0
        best_threshold = None
        best_feature = None
        for feature in X.columns:
            for threshold in set(X[feature]):
                information_gain = self.information_gain(X, y, feature, threshold)
                if information_gain >= best_information_gain:
                    best_information_gain = information_gain
                    best_threshold = threshold
                    best_feature = feature
        return best_feature, best_threshold

    def build_tree(self, X, y, depth=0):
        if self.is_splitting_finished(depth, len(X.columns), len(X)):
            return None

        best_feature, best_threshold = self.best_split(X, y)
        X_left, X_right, y_left, y_right = self.split(X, y, best_feature, best_threshold)

        left_node = self.build_tree(X_left, y_left, depth=depth + 1)
        right_node = self.build_tree(X_right, y_right, depth=depth + 1)

        value = None
        if left_node is None or right_node is None:
            true_value = len(y[y['diagnosis'] == 1])
            false_value = len(y[y['diagnosis'] == 0])
            if true_value >= false_value:
                value = 1
            else:
                value = 0

        return Node(feature=best_feature, threshold=best_threshold, left=left_node, right=right_node, value=value)

    def fit(self, X, y):
        self.root = self.build_tree(X, y)

    def predict(self, X):
        tree = self.root
        predicted_value = []
        for index in list(X.index):
            data = X.loc[index]
            current_tree = tree
            for depth in range(self.max_depth):
                if Node.is_leaf(current_tree):
                    predicted_value.append(current_tree.value)
                    break
                feature = current_tree.feature
                threshold = current_tree.threshold
                if data[feature] <= threshold:
                    current_tree = current_tree.left
                if data[feature] > threshold:
                    current_tree = current_tree.right

        return predicted_value

# %% [markdown]
# <font face="Times New Roman" size=4><div dir=ltr>
# ## Data Prepration (20 points)
# In this section, you must perform a good EDA for data. Then split it into train and validation data. We will then use the validation data to find the best model hyperparameters.

# %%
breast_cancer_pdf = pd.read_csv("breast_cancer.csv")

# %%
# TODO
breast_cancer_pdf
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 564          0
# 565          0
# 566          0
# 567          0
# 568          1
#
# [569 rows x 6 columns]

# %%
breast_cancer_pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
#  5   diagnosis        569 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 26.8 KB

# %%
breast_cancer_pdf.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness   diagnosis
# count       569.000000  569.000000
# mean          0.096360    0.627417
# std           0.014064    0.483918
# min           0.052630    0.000000
# 25%           0.086370    0.000000
# 50%           0.095870    1.000000
# 75%           0.105300    1.000000
# max           0.163400    1.000000

# %%
breast_cancer_pdf.value_counts()
# Out:
# mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  diagnosis
# 6.981        13.43         43.79           143.5      0.11700          1            1
# 14.860       16.94         94.89           673.7      0.08924          1            1
# 14.710       21.59         95.55           656.9      0.11370          0            1
# 14.740       25.42         94.70           668.6      0.08275          1            1
# 14.760       14.74         94.87           668.7      0.08875          1            1
#                                                                                    ..
# 12.200       15.21         78.01           457.9      0.08673          1            1
# 12.190       13.29         79.08           455.8      0.10660          1            1
# 12.180       20.52         77.22           458.7      0.08013          1            1
#              17.84         77.79           451.1      0.10450          1            1
# 28.110       18.47         188.50          2499.0     0.11420          0            1
# Length: 569, dtype: int64

# %%
breast_cancer_pdf.isnull().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
sns.pairplot(breast_cancer_pdf, hue='diagnosis', height=2)

# %%
def plotting(method):
    cols = 3
    rows = 2
    num_cols = breast_cancer_pdf.select_dtypes(exclude='object').columns
    fig = plt.figure(figsize=(cols*3, rows*3))
    for i, col in enumerate(num_cols):

        ax=fig.add_subplot(rows,cols,i+1)

        method(x = breast_cancer_pdf[col], ax = ax)

    fig.tight_layout()  
    plt.show()

# %%
plotting(sns.boxplot)

# %%
plotting(sns.histplot)

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(breast_cancer_pdf.corr(), annot=True, ax=ax)

# %%
X = breast_cancer_pdf.drop(['diagnosis'], axis=1)

y = breast_cancer_pdf[['diagnosis']]

x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.70, random_state=42)

# %% [markdown]
# <font face="Times New Roman" size=4><div dir=ltr>
# ## Training And Tuning Hyperparameters (20 points)
# In this section, you only need to find the best hyperparameters for your model. You can test different values and permutations of hyperparameters by adding them to the lists below. Your model must have at least accuracy=0.85 on validation data.

# %%
max_depths = [3, 4, 5, 10, 15, 20, 25, 30]
min_samples_splits = [3, 5, 8, 10, 15, 20, 25, 30]

# %%
best_max_depth = None
best_min_samples_split = None
best_accuracy = 0
best_model = None
first_time = True
for max_depth in max_depths:
    for min_samples_split in min_samples_splits:
        clf = DecisionTree(max_depth, min_samples_split)
        clf.fit(x_train, y_train)
        y_val_pred = clf.predict(x_val)
        y_train_pred = clf.predict(x_train)
        accuracy = accuracy_score(y_val_pred, y_val)
        train_accuracy = accuracy_score(y_train_pred, y_train)
        print(f"accuracy of training set for [min_samples_splits = {min_samples_split} - max_depths = {max_depth}] = {train_accuracy}")
        print(f"accuracy of validation set for [min_samples_splits = {min_samples_split} - max_depths = {max_depth}] = {accuracy}")
        print("------------------------------------------------")
        if accuracy > best_accuracy or first_time:
            best_accuracy = accuracy
            best_max_depth = max_depth
            best_min_samples_split = min_samples_split
            best_model = clf
            first_time = False
# Out:
# accuracy of training set for [min_samples_splits = 3 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 3] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 3] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 4] = 0.9176470588235294
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 4] = 0.8721804511278195
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 4] = 0.9176470588235294
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 4] = 0.8721804511278195
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 4] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 4] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 4] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 4] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 4] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 4] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 4] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 4] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 4] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 4] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 4] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 4] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 5] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 5] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 5] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 5] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 5] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 5] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 5] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 5] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 5] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 5] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 5] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 5] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 5] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 5] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 5] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 5] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 10] = 0.9529411764705882
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 10] = 0.9097744360902256
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 10] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 10] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 10] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 10] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 10] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 10] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 10] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 10] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 10] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 10] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 10] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 10] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 10] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 10] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 15] = 0.9529411764705882
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 15] = 0.9097744360902256
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 15] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 15] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 15] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 15] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 15] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 15] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 15] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 15] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 15] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 15] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 15] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 15] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 15] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 15] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 20] = 0.9529411764705882
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 20] = 0.9097744360902256
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 20] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 20] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 20] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 20] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 20] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 20] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 20] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 20] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 20] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 20] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 20] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 20] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 20] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 20] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 25] = 0.9529411764705882
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 25] = 0.9097744360902256
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 25] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 25] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 25] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 25] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 25] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 25] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 25] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 25] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 25] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 25] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 25] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 25] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 25] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 25] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 3 - max_depths = 30] = 0.9529411764705882
# accuracy of validation set for [min_samples_splits = 3 - max_depths = 30] = 0.9097744360902256
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 5 - max_depths = 30] = 0.9294117647058824
# accuracy of validation set for [min_samples_splits = 5 - max_depths = 30] = 0.9047619047619048
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 8 - max_depths = 30] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 8 - max_depths = 30] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 10 - max_depths = 30] = 0.888235294117647
# accuracy of validation set for [min_samples_splits = 10 - max_depths = 30] = 0.8421052631578947
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 15 - max_depths = 30] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 15 - max_depths = 30] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 20 - max_depths = 30] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 20 - max_depths = 30] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 25 - max_depths = 30] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 25 - max_depths = 30] = 0.8771929824561403
# ------------------------------------------------
# accuracy of training set for [min_samples_splits = 30 - max_depths = 30] = 0.8705882352941177
# accuracy of validation set for [min_samples_splits = 30 - max_depths = 30] = 0.8771929824561403
# ------------------------------------------------

# %%
print(f'best_accuracy = {best_accuracy}')
print(f'best_max_depth = {best_max_depth}')
print(f'best_min_samples_split = {best_min_samples_split}')
# Out:
# best_accuracy = 0.9097744360902256
# best_max_depth = 10
# best_min_samples_split = 3
